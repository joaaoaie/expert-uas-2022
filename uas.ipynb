# %%
import numpy as np
import pandas as pd

# %%
dataJarak = pd.read_csv('dataset.csv')
dataJarak
# Out:
#             Asal        Tujuan  Jarak  Waktu  KonfirmasiCovid
# 0      Puskesmas  SerdangWetan   5.20     11       340.000000
# 1      Puskesmas      Palasari   4.40     16       169.000000
# 2      Puskesmas     Rancagong   4.10     11       294.000000
# 3      Puskesmas         Legok   2.30      7       732.000000
# 4      Puskesmas       Babakan   0.02      1       368.000000
# 5   SerdangWetan     Puskesmas   5.30     11         0.000000
# 6   SerdangWetan      Palasari   4.70     13         0.497059
# 7   SerdangWetan     Rancagong   3.20      9         0.864706
# 8   SerdangWetan         Legok   4.00     10         2.152941
# 9   SerdangWetan       Babakan   5.30     11         1.082353
# 10      Palasari     Puskesmas   4.40     16         0.000000
# 11      Palasari  SerdangWetan   4.70     13         2.011834
# 12      Palasari     Rancagong   4.80     14         1.739645
# 13      Palasari         Legok   4.20     13         4.331361
# ...
